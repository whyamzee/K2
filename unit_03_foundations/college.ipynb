# %%
## Import pandas and matplotlib (remember "% matplotlib inline")

# %%
# %matplotlib inline
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

#import os
#print (os.getcwd())
#print (os.listdir())

# %%
## Read in the data and explore the head and tail

# %%
data = pd.read_csv('recent-grads.csv')
print (data.describe())
data.head()
data.tail()
# Out:
#              Rank   Major_code          Total  Sample_size            Men  \
# count  173.000000   173.000000     173.000000   173.000000     173.000000
# mean    87.000000  3879.815029   39167.716763   356.080925   16637.358382
# std     50.084928  1687.753140   63354.613919   618.361022   28063.394844
# min      1.000000  1100.000000     124.000000     2.000000     119.000000
# 25%     44.000000  2403.000000    4361.000000    39.000000    2110.000000
# 50%     87.000000  3608.000000   15058.000000   130.000000    5347.000000
# 75%    130.000000  5503.000000   38844.000000   338.000000   14440.000000
# max    173.000000  6403.000000  393735.000000  4212.000000  173809.000000
#
#                Women  ShareWomen       Employed      Full_time      Part_time  \
# count     173.000000  173.000000     173.000000     173.000000     173.000000
# mean    22530.358382    0.522550   31192.763006   26029.306358    8832.398844
# ...

# %%
## Drop any rows with missing values

# %%
data_discard = data.loc[(np.isnan(data['Unemployment_rate'])),data.columns]
data_discard.describe()

data = data[(np.isnan(data['Unemployment_rate'])==False)]
data.describe()
# simplier way:
# data = data.dropna()
# Out:
# /Users/yuliya/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#              Rank   Major_code          Total  Sample_size            Men  \
# count  172.000000   172.000000     172.000000   172.000000     172.000000
# mean    87.075581  3880.273256   39394.715116   358.127907   16723.877907
# std     50.221266  1692.670105   63468.993551   619.578329   28122.182046
# min      1.000000  1100.000000     609.000000     2.000000     119.000000
# 25%     43.750000  2402.750000    4559.750000    42.000000    2177.500000
# 50%     87.500000  3607.500000   15104.000000   131.000000    5434.000000
# 75%    130.250000  5503.250000   38909.750000   339.000000   14631.000000
# max    173.000000  6403.000000  393735.000000  4212.000000  173809.000000
#
#                Women  ShareWomen       Employed      Full_time      Part_time  \
# ...

# %%
## Make a scatter plot of sample size vs. median

# %%
# native pandas
#data.plot.scatter(x=['Sample_size'], y=['Median'])
# Median.min = 22000
# Median.max = 110000
# Sample.min = 2
# Sample.max = 4212
plt.scatter(x=data['Sample_size'], y=data['Median'])
plt.ylim(ymin=20000)
plt.xlim(xmin=0)
plt.show()

# %%
## Make a scatter plot of sample size vs. unemployment rate

# %%
# Unemployment.min = 0.0
# Unemployment.max = 0.177226
plt.scatter(x=data['Sample_size'], y=data['Unemployment_rate'])
plt.ylim(ymin=-0.01, ymax=0.2)
plt.xlim(xmin=0)
plt.show()

# %%
## Make a scatter plot of full time vs. median

# %%
# Fulltime.min = 111
# fulltime.max = 251540
plt.scatter(x=data['Full_time'], y=data['Median'])
plt.xlim(xmin=0)
plt.ylim(ymin=20000)
plt.show()

# %%
## Make a scatter plot of men vs. median

# %%
# Men.min = 119
# Men.max = 173809
plt.scatter(x=data['Men'], y=data['Median'])
plt.xlim(xmin=0)
plt.ylim(ymin=20000)
plt.show()

# %%
## Make a scatter plot of women vs. median

# %%
# Women.min = 0
# Women.max = 307087
plt.scatter(x=data['Women'], y=data['Median'])
plt.xlim(xmin=0)
plt.ylim(ymin=20000)
plt.show()

# %%
## Create a for loop that plots the histogram of sample size, median, employed, full time, unemployment rate, 
## men and women (remember to use the exact column titles)

# %%
cols = ['Sample_size','Median','Employed','Full_time','Unemployment_rate','Men','Women']
#cols = ['Sample_size']
for col in cols:
    plt.hist(data[col])
    plt.title(col)
    plt.ylabel('Frequency')
    plt.xlabel(col + ' value')
    plt.show()

# %%
## Make a scatter matrix of sample size and median
## Make a scatter matrix of sample size, median and unemployment rate

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(data.loc[:,['Sample_size','Median']])
scatter_matrix(data.loc[:,['Sample_size','Median','Unemployment_rate']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x117812c88>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1193c12b0>]], dtype=object)

# %%
## Make a bar plot of majors vs "ShareWomen" (you should run different slices since there are many different majors)

# %%
sample = data.loc[:,['Major_category','ShareWomen']]
sample['ShareWomen_cat'] = sample['ShareWomen'].apply(lambda x: (x // 0.1) * .1)
